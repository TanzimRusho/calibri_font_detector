# %% [markdown]
# <a href="https://colab.research.google.com/github/TanzimRusho/calibri_font_detector/blob/main/ocr_calibri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install tesseract-ocr
# !pip install pytesseract

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
glob.glob('/content/drive/My Drive/calibri_font_detector/alphabet/*')

# %%
from PIL import Image
import pytesseract
import cv2
import os
import matplotlib.pyplot as plt

image = cv2.imread( '/content/drive/My Drive/calibri_font_detector/alphabet/test0.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#gray = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
#gray = cv2.medianBlur(gray, 3)
    
# write the grayscale image to isk as a temporary file so we can
# apply OCR to it
cv2.imwrite( '/content/drive/My Drive/calibri_font_detector/alphabet/test0_processed.png', gray)
plt.imshow(gray)

# %%
img = cv2.imread('/content/drive/My Drive/calibri_font_detector/alphabet/test0_processed.png')

# %%
text = pytesseract.image_to_string(img)
print(text)
# Out:
# AaBbCcDdEeFfGgHhli
#
# JjKkLIMmMNnOoPpQq
#
# RrSsTtUuUVVWwxx/Yy
# 2Z1234567890&!?.,
